# %% [markdown]
# <a href="https://colab.research.google.com/github/ummaysumaiya0808/Facial-emotion-detection-/blob/main/Facial_emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
img = plt.imread('/content/HappyBoy.jpg')
plt.imshow(img)
plt.axis('off')
plt.title("Hlw!!! Happy")
plt.show()

# %%
import cv2

# %%
# !pip install deepface

# %%
from deepface import DeepFace

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-12-22 07:59:36 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 61.4MB/s]
# Action: age:  25%|██▌       | 1/4 [00:00<00:02,  1.16it/s]
# 24-12-22 07:59:38 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 8.39M/539M [00:00<00:06, 83.1MB/s]
#   5%|▌         | 28.3M/539M [00:00<00:03, 150MB/s]
#  11%|█         | 57.1M/539M [00:00<00:02, 212MB/s]
#  16%|█▌        | 84.4M/539M [00:00<00:01, 233MB/s]
#  20%|██        | 108M/539M [00:00<00:01, 228MB/s]
# ...

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.9734450076684673e-11,
#    'disgust': 1.4774786677518205e-18,
#    'fear': 3.98842844330765e-12,
#    'happy': 99.28774237632751,
#    'sad': 1.056371101704201e-08,
#    'surprise': 1.3143848232033406e-07,
#    'neutral': 0.7122574839740992},
#   'dominant_emotion': 'happy',
#   'region': {'x': 283,
#    'y': 211,
#    'w': 366,
#    'h': 366,
#    'left_eye': (537, 355),
#    'right_eye': (402, 355)},
#   'face_confidence': 0.92,
#   'age': 26,
#   'gender': {'Woman': 0.2773513551801443, 'Man': 99.72264170646667},
#   'dominant_gender': 'Man',
#   'race': {'asian': 100.0,
#    'indian': 3.6260445757108073e-07,
#    'black': 3.996430816193592e-15,
#    'white': 1.3602069470763922e-08,
#    'middle eastern': 2.0550899068331353e-17,
#    'latino hispanic': 1.0818165918635714e-06},
#   'dominant_race': 'asian'}]

# %% [markdown]
# So, here the dominant_emotion is happy.

# %%
type(predictions)
# Out:
# list

# %%
sad=cv2.imread('/content/sadGirl.jpg')
plt.imshow(sad)
plt.imshow(cv2.cvtColor(sad, cv2.COLOR_BGR2RGB))

# %%
predictions= DeepFace.analyze(sad)
# Out:
# Action: race: 100%|██████████| 4/4 [00:04<00:00,  1.07s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.013107148697599769,
#    'disgust': 2.491913564384163e-07,
#    'fear': 0.3013063222169876,
#    'happy': 2.6175634104674828e-06,
#    'sad': 90.52394032478333,
#    'surprise': 2.980655944284649e-07,
#    'neutral': 9.16164219379425},
#   'dominant_emotion': 'sad',
#   'region': {'x': 173,
#    'y': 87,
#    'w': 673,
#    'h': 673,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 30,
#   'gender': {'Woman': 99.6213972568512, 'Man': 0.37859680596739054},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 6.265807151794434,
#    'indian': 2.191891334950924,
#    'black': 0.9076983667910099,
#    'white': 56.45355582237244,
#    'middle eastern': 12.90002316236496,
#    'latino hispanic': 21.28102034330368},
#   'dominant_race': 'white'}]

# %% [markdown]
# So, here the dominant_emotion is Sad.

# %%
fear = plt.imread('/content/FearMan2.jpg')
plt.imshow(fear)
plt.axis('off')
plt.title("Sooo!!!!! Horrified")
plt.show()

# %%
from deepface import DeepFace
predictions= DeepFace.analyze(fear)
# Out:
# Action: race: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 6.129021197557449,
#    'disgust': 0.00036796734548261156,
#    'fear': 93.69741678237915,
#    'happy': 0.0020911542378598824,
#    'sad': 0.1698527717962861,
#    'surprise': 9.404599836670968e-05,
#    'neutral': 0.0011562015970412176},
#   'dominant_emotion': 'fear',
#   'region': {'x': 196,
#    'y': 93,
#    'w': 130,
#    'h': 130,
#    'left_eye': (275, 138),
#    'right_eye': (238, 151)},
#   'face_confidence': 0.93,
#   'age': 25,
#   'gender': {'Woman': 0.03322965349070728, 'Man': 99.9667763710022},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.001980386150535196,
#    'indian': 0.2091017784550786,
#    'black': 0.00018702423858485417,
#    'white': 34.737902879714966,
#    'middle eastern': 57.48632550239563,
#    'latino hispanic': 7.56450891494751},
#   'dominant_race': 'middle eastern'}]

# %% [markdown]
# So, here the dominant_emotion is Fear
